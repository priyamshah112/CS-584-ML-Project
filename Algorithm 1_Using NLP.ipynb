# %% [markdown]
# ### Using NLP: For Evidence-enhanced dis-information detection in crypto news space
#
# This algorithm is an implementation of a content-based recommendation system using NLP for crypto news articles. It uses a dataset of crypto news articles in the form of a CSV file with columns for year, title, text, source, and URL. It takes a user text as an input and provides relevant [ text, source, url] with relevancy score to justify how authentic or relevant that news article can be. It also provides analysis parameters to assess the summarized results.

# %%
from textblob import TextBlob

def get_sentiment_score(text):
    """
    Returns the sentiment score for a given text.
    """
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    return sentiment_score

def get_polarity_score(text):
    """
    Returns the polarity score for a given text.
    """
    blob = TextBlob(text)
    polarity_score = blob.sentiment.subjectivity
    return polarity_score

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

import numpy as np
import re
from nltk.stem import PorterStemmer
from nltk.sentiment import SentimentIntensityAnalyzer

def preprocess_text(text):
    """
    Preprocesses text by removing non-alphabetic characters, converting to lowercase, 
    tokenizing, and stemming.
    """
    ps = PorterStemmer()
    text = re.sub('[^a-zA-Z]', ' ', str(text))
    text = text.lower()
    text = text.split()
    text = [ps.stem(word) for word in text]
    text = ' '.join(text)
    return text

def get_similar_articles(query, df, n=10):
    """
    Returns a list of n tuples, where each tuple contains the [text, source, url] and its relevancy score.
    """
    # preprocess query
    query = preprocess_text(query)
    
    # preprocess text in df
    df['text'] = df['text'].apply(preprocess_text)
    
    # compute TF-IDF matrix
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(df['text'])
    
    # compute cosine similarity between query and all documents
    query_vector = vectorizer.transform([query])
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()
    
    # get indices of top n similar documents
    similar_indices = cosine_similarities.argsort()[:-n-1:-1]
    
    # create list of tuples containing [text, source, url] and relevancy score
    similar_articles = []
    for index in similar_indices:
        text = df.loc[index, 'text']
        source = df.loc[index, 'source']
        url = df.loc[index, 'url']
        score = cosine_similarities[index]
        similar_articles.append((text, source, url, score))
    
    # calculate sentiment and polarity scores
    sentiment_scores = [get_sentiment_score(text) for text, _, _, _ in similar_articles]
    polarity_scores = [get_polarity_score(text) for text, _, _, _ in similar_articles]
    
    # calculate mean and standard deviation of sentiment and polarity scores
    mean_sentiment_score = np.mean(sentiment_scores)
    std_sentiment_score = np.std(sentiment_scores)
    mean_polarity_score = np.mean(polarity_scores)
    std_polarity_score = np.std(polarity_scores)
    
    # return dictionary with analysis parameters
    analysis_params = {
        "num_similar_articles": n,
        "mean_sentiment_score": mean_sentiment_score,
        "std_sentiment_score": std_sentiment_score,
        "mean_polarity_score": mean_polarity_score,
        "std_polarity_score": std_polarity_score
    }
    
    return similar_articles, analysis_params


query = "Walmart and Litecoin Payment News Debunked by Walmart Spokesperson, LTC Prices Shudder from Fake News"
similar_articles, analysis_params = get_similar_articles(query, df)
# print list of similar articles
for article in similar_articles:
    text, source, url, score = article
    print(f"Text: {text}\nSource: {source}\nURL: {url}\nRelevancy Score: {score}\n")
    
print(f"Number of similar articles: {analysis_params['num_similar_articles']}")
print(f"Mean sentiment score: {analysis_params['mean_sentiment_score']}")
print(f"Standard deviation of sentiment score: {analysis_params['std_sentiment_score']}")
print(f"Mean polarity score: {analysis_params['mean_polarity_score']}")
print(f"Standard deviation of polarity score: {analysis_params['std_polarity_score']}")
# Out:
# Text: week ago i had the pleasur of write an articl i d dream of write for month and month on end gyft add walmart gift card ala all good thing are not meant to last for the last week bitcoin around the countri have had the pleasur of buy walmart gift card with bitcoin receiv back in the form of gyft point and in essenc spend bitcoin at walmart on ga and groceri make bitcoin a cheaper option to buy ga ha been a long stand dream of the bitcoin commun thi wa the first step toward realiz that dream and said step ha now been rever despit the loss of walmart gyft is gear to provid more to smaller busi with the launch of gyft cloud gyft inform custom via email that due to reason outsid of gyft s control they are unabl to stock walmart gift card ani longer the bitcoin commun know full well that vinni at gyft would not unlist walmart gift card from gyft s impress registri unless he wa forc to there is no doubt in my mind that the initi deci that ha culmin in today s end of gyft s support of walmart wa origin made in arkansa at walmart hq walmart gift card are no longer avail for bitcoinamazon also shun bitcoin usea jason del ray wrote in hi recod articl on amazon say no to accept bitcoin amazon isn t alon in thi stanc among big e commerc site ebay walmart com target com and other big name have shown no sign of move toward accept probabl the most well known onlin seller to accept the digit currenc is overstock com which sell furnitur onlin and ha a compar modest market cap of million compar to overstock and tigerdirect amazon and walmart are much much larger it seem that they have both dismiss bitcoin as an annoy fli not worthi of real attent amazon s payment team head tom taylor also told recod that we re not hear from custom that it s right for them and don t have ani plan within amazon to engag bitcoin as reveal by industri sourc close to amazon and hint at by amazon s payment team amazon may be step into the financ sphere soon to contend with visa mastercard amex paypal as oppo to just pay their usuri fee some reader will rememb that amazon previou relea amazoncoin as part of a qe program to stimul app develop for their kindl amazon seem to have turn their back on bitcoin howev they are clearli still open to the concept of digit currenc facebook just might be the same way
# Source: bitcoin_announcements
# URL: https://www.ccn.com/walmart-ends-gyfts-walmart-gift-cards-fellow-e-commerce-giant-amazon-also-shuns-bitcoin/
# Relevancy Score: 0.3435292708922946
#
# Text: a new patent file find retail giant walmart seek to util blockchain technolog to perfect a smarter packag deliveri track system in an applic relea by the u s patent and trademark offic uspto on thursday walmart describ a smart packag that would includ a devic which would record inform on a blockchain regard the content of the packag it environ condit it locat and more it also suggest that it smart packag could be use in tandem with other emerg technolog includ autonom vehicl such as drone the patent wa first submit in august of and notabl build on a file walmart submit for a blockchain base drone packag deliveri track system last year walmart explain in the file that onlin shop ha creat ship challeng for retail particularli with regard to perish product requir temperatur control thu necessit further innov walmart write in the applic these onlin custom mani time seek to purcha item that may requir a control environ and further seek to have greater secur in the ship packag that the item are ship in the applic state that the blockchain compon will be encrypt into the devic and will have key address along the chain of the packag s custodi includ hash with a seller privat key address a courier privat key address and a buyer privat key address in addit to it deliveri drone aspir walmart ha sought to appli blockchain technolog to other area of it busi last year it join kroger nestl and other food industri firm in a partnership with ibm to use the blockchain to improv food traceabl it back a similar effort in china with jd com in decemb walmart storefront imag via shutterstockth leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: news
# URL: https://www.coindesk.com/walmart-using-blockchain-tech-make-shipping-smarter/
# Relevancy Score: 0.3226898643991455
#
# Text: walmart ha develop a blockchain pilot focu on china s massiv pork industri suppli chain built in collabor with ibm and beij s tsinghua univ the pilot is part of two separ but parallel push by walmart and the chine govern to make suppli chain data more accur and therefor safer ibm s head of global suppli chain solut paul chang explain that the pilot if implement could also give walmart a bigger slice of china s lucr pork industri chang told coindesk it s not just import for china but for walmart to realli succeed in china it is the most consum meat of the most popul countri in the world china is expect to consum million ton of pork thi year accord to a recent usda report and that s a slight decrea from origin forecast due to rise price for exampl a wharton studi last year found that china s high domest pork price are tie directli to food safeti concern which is where the walmart pilot come in the blockchain prototyp wa announc today as walmart open it new walmart food safeti collabor center in beij the offic is intend to promot a more transpar food system in china blockchain includ start from scratchto build the pilot a walmart team in china compri of suppli chain staffer logist and food safeti expert partner with tsinghua univ s nation engin laboratori for e commerc technolog construct use technolog from the hyperledg blockchain project the pilot is be posit as a way to ensur the accuraci of farm origin detail batch number factori and process data expir date storag temperatur and ship detail in the begin the pilot will be run on three node one manag by ibm one by walmart and anoth by an unnam supplier chang said didn t want to be disclo but to give an idea of how larg these supplier can be chang a year veteran of suppli chain traceabl said that by the time the project scale to node the industri could save billion of dollar that s becau when food is sold to a consum at a walmart store each individu item will have been authent use the blockchain system to creat a transpar and secur record accord to a statement a record creat in the distribut ledger can also help the retail better manag the shelf life of it product in individu store safer suppli chainsfollow multipl report of contamin in both china s food and drug industri the china food and drug administr earlier thi year propo the adopt of measur to improv product traceabl while the push for more stringent suppli chain control by the govern wa cite in today s statement as a critic step toward help elimin contamin increa regul is usual accompani by higher price in may regul of china s babi milk powder industri wa credit for increa competit and decrea revenu in a south china morn post report though walmart doesn t break down it revenu number by countri in it annual report a reuter articl last year indic that the retail wa fall short of it plan for china to account for a quarter of it global retail growth with an estim tn to be save by move global suppli chain to a blockchain walmart stand to not onli help china make it food safer but cut corner on cost mango and beyondbut chang said ibm is alreadi well advanc in anoth effort that implement lesson learn from the project in a total differ industri he describ an unannounc project current underway to transport mango as slightli smaller in scope but much broader in term of the number of agenc we are start thi with a pretti big splash do pork in china said chang but we alreadi have plan to launch into a multin plan to track mango from south american to the us from there he expect ibm and it competitor in the blockchain suppli chain space to move from one commod to anoth he conclud thi is the miss link that i think could final encourag the industri to adopt thi technolog for the benefit of effici trade and the benefit of the consum they serv piglet imag via shutterstockth leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: feature
# URL: https://www.coindesk.com/walmart-blockchain-pilot-china-pork-market/
# Relevancy Score: 0.31069670901336593
#
# Text: mobil gift card provid gyft ha announc via an email to it custom that it no longer offer user the abil to purcha walmart gift card on it platform gyft which accept bitcoin and provid gyft point back to digit currenc buyer ad the us retail giant to it network on th march to great fanfar as walmart wa long one of the most request retail by gyft user the compani inform custom of the chang in it offer via a th april email read the messag due to circumst beyond our control we need to remov walmart from our list of particip retail effect april rest assur that we are do everyth in our power to bring them back up as soon as possibl gyft and it ceo vinni lingham have been outspoken about their support for bitcoin with lingham most recent pen a lengthi post on how bitcoin play a key role in the growth of the compani the san francisco base compani began accept bitcoin in may through a partnership with bitpay more detailsthough new buyer won t be abl to purcha walmart gift card gyft indic that exist walmart gift card purcha on it platform can still be redeem the compani long one of bitcoin s most support compani in the wider tech ecosystem stress that bitcoin user who were dissatisfi with the deci should get in touch with walmart regard the matter said the email messag if you are as disappoint as we are about thi deci by walmart plea email them at help walmart com and let them know how you feel about it gyft will continu talk with walmartspeak to coindesk lingham indic that gyft would seek to learn more about the deci and to continu to speak to walmart about relist it gift card still lingham wasn t optimist that the retail s polici would chang said lingham we will continu to talk to them but it s a giant organ i can t speak to their reason at thi stage as point out in the email howev gyft still provid bitcoin user access to a number of mainstream merchant notabl thi includ minnesota base retail giant target the third largest in the us which join the gyft network in novemb imag credit katherin well shutterstock comth leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: news
# URL: https://www.coindesk.com/gyft-forced-end-walmart-gift-card-support/
# Relevancy Score: 0.308160979948455
#
# Text: global retail giant walmart host a present on it work with blockchain dure an annual investor event last week the compani began work with ibm and tsinghua univ of beij last year to test blockchain base suppli chain applic with a particular focu on china s massiv pork market in follow up statement walmart indic it want to appli the tech to variou area and more recent coindesk report the compani is look at blockchain as a track solut for unman deliveri vehicl the result of the initi trial though will arguabl set the tenor for walmart s use of blockchain and accord to the firm it food focu test ha produc veri encourag result and thi is onli the begin accord to walmart which said of the present thi is just the start of our blockchain explor we plan to continu to test the technolog by includ more data attribut for exampl and we will continu to test how we can use it to improv food traceabl and transpar by collabor with other throughout the suppli chain thi mean farmer and supplier and other retail walmart explain that the technolog ha help it reduc the time it take to track food from day to minut enabl more effect respon in the event that taint product are discov thi will help enabl preci and rapid recal to preserv consum trust in the food industri while increa traceabl and transpar of the food system the firm said imag credit zhao jian kang shutterstock comth leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: news
# URL: https://www.coindesk.com/walmart-blockchain-food-tracking-test-results-encouraging/
# Relevancy Score: 0.30292898779253236
#
# Text: walmart which wa one of the first major retail to explor the use of blockchain technolog in it suppli chain file a number of trademark applic last month
# Source: CryptoNews
# URL: https://cryptonews.com/news/flurry-of-walmart-patents-show-willingness-embrace-crypto-nfts-metaverse.htm
# Relevancy Score: 0.2856717883678242
#
# Text: a recent relea file by the u s patent and trademark offic uspto outlin a blockchain base framework that walmart ha envi as part of it effort to expand it digit servic for retail shopper walmart s blockchain pushfil in and grant on may the document is an exampl of walmart s push to embrac digit technolog for augment it intellectu properti hold and it add to an impress arsen featur a number rang from parcel track system to iot as per the document walmart s propo system enabl the track of retail product brought by a custom thi is achiev by allow a custom storeh or retail to regist a product after purcha choo a defin price for resal to individu while use walmart s framework as a digit marketplac as state in the patent the increa competit from non tradit shop mechan as an incent for brick and mortar retail to stay ahead of new technolog that could improv custom experi furthermor the patent specifi that the innov is not limit to retail as individu custom often use an item for a limit period and wish to sell it later on howev thi involv low awar on how to execut the sale as custom are left to their own devic to arrang for a subsequ resal walmart ha file to patent a blockchain base digit marketplacehowev the describ platform is said to provid addit support to greatli ea and facilit their later resel of item while encompass a varieti of interfac such as web browser mobil platform or a physic point of sale the propo is similar to a recent file patent which describ the retail giant s intent to power up a fleet of deliveri van via the blockchain howev the latest patent detail a distribut deliveri record blockchain which updat everi transact as the product are purcha in bulk sold to custom and handl by courier the blockchain mechanismfor make a transact the seller and courier are requir to provid their privat key onc match the transact is instantli broadcast to the network though it may requir verif from the buyer seller and courier prior to be ad to the blockchain later when the buyer collect the packag the courier is expect to util their privat key for confirm the handov which immedi updat the blockchain with the transact and mark the end of the purcha cycl it remain to be seen whether walmart s vision will becom a realiti though as the firm ha file for a number of blockchain patent over the year but ha been hesit to merg them into it day to day oper
# Source: blockchain_news
# URL: https://www.ccn.com/walmart-files-patent-for-blockchain-based-digital-marketplace/
# Relevancy Score: 0.2712080528097639
#
# Text: the day that mani bitcoin have been secretli wait for ha final arriv gyft is now stock walmart gyft card vinni gyft s ceo announc the addit to the gyft arsen via twitter and a reddit post earlier today we are so so so so excit to announc that walmart is final on gyft enjoy gyfter shopyourwalmartheartsouthttp gyft co uiyhd j walmart gift card minimum valu are avail for bitcoin via gyftbitcoin are now abl to use bitcoin to buy gyft card to spend at walmart or walmart s subsidiari sam s club everyth in the diaspora of consum item offer by walmart is now avail for purcha with bitcoin gyft offer back in the form of loyalti point that can be use on addit gyft card thi is equiv to a discount to user for use bitcoin despit the servic that gyft ha offer to the bitcoin commun some still question whi one would go through the troubl of buy a gift card to purcha an item whi would i use bitcoin and gyft the fact of the matter is i can use the instant buy function at coinba to purcha bitcoin for in fee i can then purcha a gift card for walmart from gyft and pay use bitcoin i would then receiv of the fiat valu of bitcoin that i just spent back in gyft point some simpl arithmet bring me to the conclu that for ani walmart purcha greater than i would be better off use bitcoin via gyft than cash what walmart or sam s club purcha do you make on a regular basi that total more than for myself at least i can name a few ga groceri etc bitcoin on reddit seem to agr with me some even hope that walmart allow their gift card to be sold for bitcoin is a step toward walmart accept bitcoin themselv without gyft as a middleman unfortun i highli doubt that is the ration as gyft will not reveal their proprietari user data to walmart to use your bitcoin purcha walmart gift card at an unattend ga pump involv the small extra step of exchang your gyft card for a physic gift card at ani walmart or sam s club custom servic center gyft is a bitcoin companya u vinnyatgyft is wont to remind naysay gyft is a bitcoin compani here are vinni s step for integr your compani as a bitcoin compani into the bitcoin economi start accept bitcoin but don t convert it all to fiat just convert what you need for cash flow purpo we have to repurcha gift card as inventori our biggest cost outsid of salari and tax the more you keep and spend in btc the stronger the economi will becom store as much of your bitcoin sale margin in btc where possibl start give your employ bitcoin even if they earn and need fiat to surviv get everyon in the compani use it where possibl we even have the expensifi btc reimbur option at gyft we give all our employ bitcoin from time to time in addit to their salari pay your supplier in bitcoin at least those who will accept it it s get a lot easier to these day luckili and circul bitcoin is the best way to strengthen thi economi don t hoard bitcoin in your compani either spend them they are onli worth what they are worth at the point in time you spent them have no regret we recent paid a real bitcoin compani over btc in octob they held the coin and made more than x their money in fiat equiv i m realli happi for them and it s good for the economi we didn t lose out on that gain as we had earmark those coin for them so we book it at the dollar cost no loss to us but a gain to them pass your credit card save back your custom we give back for all bitcoin purcha all compani accept bitcoin should do someth like thi becau if they are not they are essenti charg you more than their credit card custom who earn point use a credit card we have found that in purcha at gyft now includ redeem gyft point earn from our back as part of their purcha it s been a fantast loyalti driver for us if you convert cost into a benefit and you will find a win valu proposit for custom in everyth you do the full text of vinnyatgyft s thought on what is a bitcoin compani as alway stay tune to ccn for more crypto news
# Source: bitcoin_announcements
# URL: https://www.ccn.com/gyft-adds-walmart-use-bitcoin-at-walmart-or-sams-club-for-gas-or-groceries-and-save-3/
# Relevancy Score: 0.2651673547007007
#
# Text: been too busi dure thi shorter work week befor you dive headfirst into the long weekend check out our biggest news headlin from the last seven day bicoin price top as china fear subsid it had been rumour for a coupl of week that peopl s bank of china had issu a deadlin for all bank in the countri to cut off bitcoin exchang the th april deadlin came and went and it wa busi as usual at least for btc china the price of bitcoin rose back up past mid week follow thi news gyft no longer offer walmart gift card mobil card provid gyft wa forc to abruptli end walmart gift card support the compani sent an email to it user inform them it wa no longer offer walmart gift card walmart wa one of the most request retail on the site have been ad onli a few week ago on th march amazon decid against accept bitcoin amazon is anoth compani that is offici not interest in accept bitcoin the compani s payment head tom taylor said amazon had consid bitcoin but decid against it it is possibl amazon may be develop an in hou digit payment servic marijuana vend machin accept bitcoin bill as the first of it kind in america zazzz is a marijuana vend machin that will not be place behind ani sale counter it wa unveil in colorado last week and accept cash credit or bitcoin wish all the reader a happi bank holiday or long weekend as we call it in north america the leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: news
# URL: https://www.coindesk.com/video-roundup-bitcoin-news-18th-april-2014/
# Relevancy Score: 0.2603214080625509
#
# Text: autom deliveri car or truck connect via blockchain could one day deliv packag for walmart new patent file suggest the retail giant hint at the possibl use case in an applic file with the u s patent and trademark offic uspto back in octob and publish thursday per the document the patent center around technolog tool to secur restrict access area at a custom s home that would receiv packag from the autonom ground vehicl avg as walmart call them much of the applic itself doesn t mention the technolog but at one point walmart mention how blockchain could serv as part of a solut for authent base access and encrypt that would allow the vehicl to access those restrict area addit that distribut network could serv as a way to track and authent the good themselv as the applic explain when a custom interact with a product the custom is permit to do so via a privat or public authent key in respon new block may be ad to subsequ root block which will contain inform relat to the date and time a product deliv by the agv wa access as well as the authent key that access the product walmart wrote in the applic that it propo system could increa custom loyalti due to the signif conveni it would provid likewi it ad that the system would like cut cost becau of it autom natur at the expen of deliveri driver who might otherwi serv in that capac howev ind the applic further cement the impress that wal mart is look at blockchain as a possibl tool for improv the autom of it servic as coindesk report in march the retail which is separ research blockchain as a mean to track food shipment file a patent applic aim at creat a smart courier system walmart trailer imag via shutterstockth leader in blockchain news coindesk is a media outlet that strive for the highest journalist standard and abid by a strict set of editori polici
# Source: news
# URL: https://www.coindesk.com/walmart-envisions-blockchain-powered-delivery-fleets/
# Relevancy Score: 0.2562907813280027
#
# Number of similar articles: 10
# Mean sentiment score: 0.06501299226163085
# Standard deviation of sentiment score: 0.060099302742572205
# Mean polarity score: 0.40925166040176963
# Standard deviation of polarity score: 0.09215631159297351

# %% [markdown]
# #### Output Result Understanding
#
# The output analysis parameters suggest the following:
#
# Number of similar articles: 10: This indicates that the algorithm has retrieved 10 most similar articles from the dataset for the given query text.
#
# Mean sentiment score: 0.06501299226163085: This is the average sentiment score of the retrieved articles. The sentiment score ranges from -1 (most negative) to 1 (most positive), with 0 being neutral. The mean sentiment score of 0.065 indicates that the retrieved articles are slightly positive.
#
# Standard deviation of sentiment score: 0.060099302742572205: This value indicates the variability in the sentiment scores of the retrieved articles. A lower standard deviation indicates that the sentiment scores are clustered closely around the mean, while a higher standard deviation indicates greater variability in the scores. The relatively low standard deviation of 0.060 suggests that the sentiment scores of the retrieved articles are relatively consistent.
#
# Mean polarity score: 0.40925166040176963: This is the average polarity score of the retrieved articles. The polarity score ranges from 0 (most objective) to 1 (most subjective). The mean polarity score of 0.409 indicates that the retrieved articles are slightly subjective.
#
# Standard deviation of polarity score: 0.09215631159297351: This value indicates the variability in the polarity scores of the retrieved articles. A lower standard deviation indicates that the polarity scores are clustered closely around the mean, while a higher standard deviation indicates greater variability in the scores. The relatively high standard deviation of 0.092 suggests that the polarity scores of the retrieved articles are relatively diverse.

# %% [markdown]
# #### Code Explanation
#
# The function get_similar_articles takes a query string, a dataframe df containing the news articles, and an optional parameter n for the number of similar articles to return (default 10). The function first preprocesses the query string and the text of the news articles using a set of text preprocessing techniques such as removing non-alphabetic characters, converting to lowercase, tokenizing, and stemming.
#
# Then it computes the TF-IDF (term frequency-inverse document frequency) matrix, which is a numerical statistic that reflects how important a word is to a document in a collection. It then computes the cosine similarity between the query and all the documents in the dataset using the TF-IDF matrix. Cosine similarity is a measure of similarity between two non-zero vectors of an inner product space.
#
# It then returns a list of n tuples, where each tuple contains the text of the article, its source, its URL, and its relevancy score, sorted by the relevancy score in descending order. The function also calculates sentiment and polarity scores for each article using the TextBlob library, which is a Python library for processing textual data. The sentiment score measures the overall positive or negative sentiment of the article, while the polarity score measures the degree of subjectivity of the article.
#
# Finally, the function returns a dictionary with various analysis parameters, such as the number of similar articles, the mean sentiment score, the standard deviation of the sentiment score, the mean polarity score, and the standard deviation of the polarity score.
#
# In the main code, a sample query is provided and passed to the get_similar_articles function, which returns a list of similar articles and analysis parameters. The list of similar articles is printed to the console along with their source, URL, and relevancy score. The analysis parameters are also printed to the console.
#
# Overall, this code implements a content-based recommendation system for news articles that uses a combination of text preprocessing techniques, TF-IDF matrix, and cosine similarity to recommend similar articles based on a query string. It also provides sentiment and polarity scores for each recommended article.
